# %% [markdown]
# # MambaHSISR — Hyperspectral Super-Resolution Training
#
# **MambaHSISR** (TGRS 2025, state-space model) for 6× EMIT→CNMF GT upsampling.
#
# 1. Setup & Drive
# 2. Install mamba-ssm (CUDA compilation)
# 3. Data copy
# 4. Training
# 5. Evaluation

# %% [markdown]
# ## 1. Setup

# %%
import wandb
wandb.login()

# %%
from google.colab import drive, userdata
drive.mount('/content/drive')

import os, textwrap
os.environ['GH_USER'] = userdata.get('GH_USER')
os.environ['GH_TOKEN'] = userdata.get('GH_TOKEN')

askpass_path = '/tmp/gh_askpass.sh'
with open(askpass_path, 'w') as f:
    f.write(textwrap.dedent('''\
        #!/bin/sh\n\
        case \"$1\" in\n\
          *Username*) echo \"$GH_USER\" ;;\n\
          *Password*) echo \"$GH_TOKEN\" ;;\n\
          *) echo \"\" ;;\n\
        esac\n\
    '''))
os.chmod(askpass_path, 0o700)
os.environ['GIT_ASKPASS'] = askpass_path
os.environ['GIT_TERMINAL_PROMPT'] = '0'

# !git clone https://github.com/incredet/HyperSpectralSuperResolution.git 2>/dev/null || echo 'Repo already cloned'

# %% [markdown]
# ## 2. Install mamba-ssm
#
# This compiles CUDA kernels — takes ~3-5 min on first run. If it fails, check that the runtime has a GPU (Runtime → Change runtime type → A100).

# %%
# !pip install rasterio wandb pyyaml tqdm einops timm -q

# mamba-ssm has no prebuilt wheels for recent PyTorch+CUDA — builds from source (~3-5 min)
import os
os.environ['CAUSAL_CONV1D_FORCE_BUILD'] = 'TRUE'
os.environ['MAMBA_FORCE_BUILD'] = 'TRUE'
# !pip install causal-conv1d mamba-ssm -q

# %%
# Verify mamba-ssm installed correctly
import torch
print(f'PyTorch: {torch.__version__}, CUDA: {torch.cuda.get_device_name(0)}')
from mamba_ssm.ops.selective_scan_interface import selective_scan_fn
print('mamba-ssm OK')

# %% [markdown]
# ## 3. Data

# %%
import shutil
from pathlib import Path

src = Path('/content/drive/Shareddrives/HyperResData/EMIT_S-2_Matches/2026-04-02/zips_cnmf')
dst = Path('/content/data/zips_cnmf')

if not dst.exists():
    print(f'Copying {sum(1 for _ in src.glob("*.zip"))} zips to local disk...')
    shutil.copytree(src, dst)
    print('Done')
else:
    print(f'Data already copied ({sum(1 for _ in dst.glob("*.zip"))} zips)')

# %%
# %cd /content/HyperSpectralSuperResolution/training
# !git pull

# %% [markdown]
# ## 4. Training

# %%
# !python train.py \
    --config configs/mambahsisr_colab.yaml

# %%
# Resume from checkpoint (uncomment if resuming)
# !python train.py \
#     --config configs/mambahsisr_colab.yaml \
#     --resume /content/drive/Shareddrives/HyperResData/EMIT_S-2_Matches/experiments/mambahsisr-L1/models/iter_50000.pth

# %% [markdown]
# ## 5. Evaluation

# %%
# !python evaluate.py \
    --config configs/mambahsisr_colab.yaml \
    --checkpoint /content/drive/Shareddrives/HyperResData/EMIT_S-2_Matches/experiments/mambahsisr-L1/models/best.pth \
    --n-vis 8

# %%
from IPython.display import display, Image
from pathlib import Path

fig_dir = Path('/content/drive/Shareddrives/HyperResData/EMIT_S-2_Matches/experiments/mambahsisr-L1/eval_test/figures')
for png in sorted(fig_dir.glob('*_main.png'))[:4]:
    print(png.name)
    display(Image(filename=str(png), width=800))
